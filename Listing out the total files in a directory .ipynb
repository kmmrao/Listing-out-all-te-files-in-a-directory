# %%
import os

# %%
path = r'D:\Downloads\MOD04_L2\2018001'

# %%
dir_list = os.listdir(path)

# %%
dir_list[0]
# Out:
# 'MOD04_L2.A2018001.0000.061.2018003202444.hdf'

# %%
dir_list
# Out:
# ['MOD04_L2.A2018001.0000.061.2018003202444.hdf',
#  'MOD04_L2.A2018001.0005.061.2018003202614.hdf',
#  'MOD04_L2.A2018001.0010.061.2018003202359.hdf',
#  'MOD04_L2.A2018001.0015.061.2018003202659.hdf',
#  'MOD04_L2.A2018001.0020.061.2018003202430.hdf',
#  'MOD04_L2.A2018001.0025.061.2018003202309.hdf',
#  'MOD04_L2.A2018001.0030.061.2018003202614.hdf',
#  'MOD04_L2.A2018001.0035.061.2018003202406.hdf',
#  'MOD04_L2.A2018001.0040.061.2018003202430.hdf',
#  'MOD04_L2.A2018001.0130.061.2018003202342.hdf',
#  'MOD04_L2.A2018001.0135.061.2018003202953.hdf',
#  'MOD04_L2.A2018001.0140.061.2018003202604.hdf',
#  'MOD04_L2.A2018001.0145.061.2018003202458.hdf',
#  'MOD04_L2.A2018001.0150.061.2018003202558.hdf',
#  'MOD04_L2.A2018001.0155.061.2018003202734.hdf',
#  'MOD04_L2.A2018001.0200.061.2018003202535.hdf',
#  'MOD04_L2.A2018001.0205.061.2018003202900.hdf',
#  'MOD04_L2.A2018001.0210.061.2018003202530.hdf',
#  'MOD04_L2.A2018001.0215.061.2018003202305.hdf',
# ...
